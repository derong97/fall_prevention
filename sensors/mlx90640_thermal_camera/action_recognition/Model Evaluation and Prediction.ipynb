# %% [markdown]
# # Evaluation

# %%
# !python evaluate.py --arch custom --checkpoint ./save_weights/custom.pt
# Out:
# Overall Accuracy: 100.0%
#
# Per-class Accuracy
#    sit: 100.0%
#    stand: 100.0%
#    bend: 100.0%
#    inaction: 100.0%
#    tampered: 100.0%
#
# Confusion Matrix:
# [[31.  0.  0.  0.  0.]
#  [ 0. 31.  0.  0.  0.]
#  [ 0.  0. 31.  0.  0.]
#  [ 0.  0.  0. 31.  0.]
#  [ 0.  0.  0.  0. 31.]]

# %% [markdown]
# # Prediction

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/sit/sit_002.npy
# Out:
# Prediction: sit

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/stand/stand_004.npy
# Out:
# Prediction: stand

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/bend/bend_120.npy
# Out:
# Prediction: bend

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/inaction/inaction_147.npy
# Out:
# Prediction: inaction

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/tampered/tampered_101.npy
# Out:
# Prediction: tampered
