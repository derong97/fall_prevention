# %% [markdown]
# # Evaluation

# %%
# !python evaluate.py --arch custom --checkpoint ./save_weights/custom.pt
# Out:
# Overall Accuracy: 99.6%
#
# Per-class Accuracy
#    sit: 100.0%
#    stand: 100.0%
#    bend: 100.0%
#    tampered: 98.4%
#
# Confusion Matrix:
# [[61.  0.  0.  0.]
#  [ 0. 60.  0.  0.]
#  [ 0.  0. 60.  0.]
#  [ 1.  0.  0. 60.]]

# %% [markdown]
# # Prediction

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/sit/sit_576.npy
# Out:
# Prediction: sit

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/stand/stand_563.npy
# Out:
# Prediction: stand

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/bend/bend_586.npy
# Out:
# Prediction: bend

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/tampered/tampered_592.npy
# Out:
# Prediction: tampered
