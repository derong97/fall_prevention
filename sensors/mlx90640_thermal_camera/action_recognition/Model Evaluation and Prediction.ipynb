# %% [markdown]
# # Evaluation

# %%
# !python evaluate.py --arch custom --checkpoint ./save_weights/custom.pt
# Out:
# Overall Accuracy: 98.1%
#
# Per-class Accuracy
#    sit: 100.0%
#    stand: 95.1%
#    bend: 100.0%
#    tampered: 97.5%
#
# Confusion Matrix:
# [[41.  0.  0.  0.]
#  [ 2. 39.  0.  0.]
#  [ 0.  0. 40.  0.]
#  [ 0.  1.  0. 39.]]

# %% [markdown]
# # Prediction

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/sit/sit_368.npy
# Out:
# Prediction: sit

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/stand/stand_391.npy
# Out:
# Prediction: stand

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/bend/bend_363.npy
# Out:
# Prediction: bend

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/tampered/tampered_387.npy
# Out:
# Prediction: tampered
