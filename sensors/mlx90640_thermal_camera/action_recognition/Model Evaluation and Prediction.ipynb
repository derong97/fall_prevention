# %% [markdown]
# # Evaluation

# %%
# !python evaluate.py --arch custom --checkpoint ./save_weights/custom.pt
# Out:
# Overall Accuracy: 99.7%
#
# Per-class Accuracy
#    sit: 100.0%
#    stand: 98.8%
#    bend: 100.0%
#    tampered: 100.0%
#
# Confusion Matrix:
# [[81.  0.  0.  0.]
#  [ 0. 80.  1.  0.]
#  [ 0.  0. 82.  0.]
#  [ 0.  0.  0. 80.]]

# %% [markdown]
# # Prediction

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/sit/sit_772.npy
# Out:
# Prediction: sit

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/stand/stand_643.npy
# Out:
# Prediction: stand

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/bend/bend_626.npy
# Out:
# Prediction: bend

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/tampered/tampered_791.npy
# Out:
# Prediction: tampered
