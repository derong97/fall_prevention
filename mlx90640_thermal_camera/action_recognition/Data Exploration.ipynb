# %% [markdown]
# # Describe Dataset

# %%
from dataset import *
from utils import *
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
# Initialize dataset
train_ds = MLX90640_Dataset('train')
val_ds = MLX90640_Dataset('val')
test_ds = MLX90640_Dataset('test')

# %%
# Describe dataset
train_ds.describe()
val_ds.describe()
test_ds.describe()
# Out:
# This is the train dataset from our self-collected MLX90640 dataset used for Capstone.
# It contains a total of 983 videos.
# The videos are stored in the following locations and each one contains the following number of videos:
#  - sit, in folder data/train/sit: 210 videos.
#  - stand, in folder data/train/stand: 210 videos.
#  - bend, in folder data/train/bend: 211 videos.
#  - inaction, in folder data/train/inaction: 212 videos.
#  - tampered, in folder data/train/tampered: 140 videos.
#
# This is the val dataset from our self-collected MLX90640 dataset used for Capstone.
# It contains a total of 280 videos.
# The videos are stored in the following locations and each one contains the following number of videos:
#  - sit, in folder data/val/sit: 60 videos.
#  - stand, in folder data/val/stand: 60 videos.
#  - bend, in folder data/val/bend: 60 videos.
#  - inaction, in folder data/val/inaction: 60 videos.
#  - tampered, in folder data/val/tampered: 40 videos.
#
# This is the test dataset from our self-collected MLX90640 dataset used for Capstone.
# It contains a total of 144 videos.
# The videos are stored in the following locations and each one contains the following number of videos:
#  - sit, in folder data/test/sit: 31 videos.
#  - stand, in folder data/test/stand: 31 videos.
#  - bend, in folder data/test/bend: 31 videos.
#  - inaction, in folder data/test/inaction: 31 videos.
#  - tampered, in folder data/test/tampered: 20 videos.

# %% [markdown]
# # Plot distribution
# Plots bar graphs of the class distributions of train, val and test set over the 3 classes: sit, stand and tilt.

# %%
# Plot distribution

labels = train_ds.dataset_numbers.keys()
train_num = train_ds.dataset_numbers.values()
val_num = val_ds.dataset_numbers.values()
test_num = test_ds.dataset_numbers.values()

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots()
ax.bar(x - width, train_num, width, label='Train')
ax.bar(x, val_num, width, label='Validation')
ax.bar(x + width, test_num, width, label='Test')

ax.set_title('No. of videos per class')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %%
# Show the processed frames
test_ds.show_video('sit', 0)

# %%
test_ds.show_video('stand', 0)

# %%
test_ds.show_video('bend', 0)

# %%
test_ds.show_video('inaction', 0)

# %%
test_ds.show_video('tampered', 0)
