# %% [markdown]
# # Evaluation

# %%
# !python evaluate.py --arch custom --checkpoint ./save_weights/custom.pt
# Out:
# Overall Accuracy: 45.5%
#
# Per-class Accuracy
#    sit: 0.0%
#    stand: 36.4%
#    tilt: 100.0%
#
# Confusion Matrix:
# [[ 0.  0. 11.]
#  [ 0.  4.  7.]
#  [ 0.  0. 11.]]

# %% [markdown]
# # Prediction

# %%
# %run predict.py --arch custom --checkpoint ./save_weights/custom.pt --video_path data/test/stand/stand_012.npy
# Out:
# Prediction: stand
