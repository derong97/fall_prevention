# %%
from dataset import *
from torch.utils.data import DataLoader
from utils import *

# %%
# Initialize dataset
train_ds = MLX90640_Dataset('train')
val_ds = MLX90640_Dataset('val')
test_ds = MLX90640_Dataset('test')

# %%
# Describe dataset
train_ds.describe()
val_ds.describe()
test_ds.describe()
# Out:
# This is the train dataset from our self-collected MLX90640 dataset used for Capstone.
# It contains a total of 207 videos.
# The videos are stored in the following locations and each one contains the following number of videos:
#  - sit, in folder data/train/sit: 69 videos.
#  - stand, in folder data/train/stand: 69 videos.
#  - tilt, in folder data/train/tilt: 69 videos.
#
# This is the val dataset from our self-collected MLX90640 dataset used for Capstone.
# It contains a total of 57 videos.
# The videos are stored in the following locations and each one contains the following number of videos:
#  - sit, in folder data/val/sit: 19 videos.
#  - stand, in folder data/val/stand: 19 videos.
#  - tilt, in folder data/val/tilt: 19 videos.
#
# This is the test dataset from our self-collected MLX90640 dataset used for Capstone.
# It contains a total of 33 videos.
# The videos are stored in the following locations and each one contains the following number of videos:
# ...

# %% [markdown]
# # Graphs
# These graphs are plotted to show the distribution of videos among classes.

# %%
plot_class_distribution()

# %%
# Show the processed frames of ds without preprocessing
test_ds.show_video('sit', 0)

# %%
test_ds.show_video('stand', 0)

# %%
test_ds.show_video('tilt', 0)
